# %%
print("hii")
# Out:
# hii

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="WHzX5kSbytxfLmlWAEXI")
project = rf.workspace("jp-icc04").project("train_animal_dectection")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Train_animal_dectection-1 to yolov11:: 100%|██████████| 2603/2603 [00:10<00:00, 258.90it/s]
# Extracting Dataset Version Zip to Train_animal_dectection-1 in yolov11:: 100%|██████████| 162/162 [00:00<00:00, 634.43it/s]
